# %%
import pandas as pd

import os
import glob

import re

# %% [markdown]
# ### Construct full 'national' Dataframe from all state CSV files

# %%
files = glob.glob('data/state_files/*.csv')

# %%
li = []

for file in files:
    df = pd.read_csv(file, index_col=None, header=0)
    li.append(df)

# %%
frame = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# ### Extract the Genus
# functionally: the first capital 'word'

# %%
def genus_extract(row):
    try: 
        genus = re.search('([A-Z][a-z]+)', row['Scientific Name with Author'])
        return genus[0]
    except:
        genus = None

# %%
frame['Genus'] = frame.apply(lambda row: genus_extract(row), axis=1)

# %% [markdown]
# ### Extract full scientific names
# functionally: the Genus + all the lower case 'words' of the "scientific name" (Eliminating the author names)

# %%
frame
# Out:
#        Symbol Synonym Symbol             Scientific Name with Author  \
# 0        ABFR            NaN             Abies fraseri (Pursh) Poir.
# 1        ABFR           PIFR                     Pinus fraseri Pursh
# 2       ABIES            NaN                             Abies Mill.
# 3       ABPR3            NaN                    Abrus precatorius L.
# 4       ABPR3          ABAB2  Abrus abrus (L.) W. Wight, nom. inval.
# ...       ...            ...                                     ...
# 684951  ZIVEG          TOGR3  Toxicoscordion gramineum (Rydb.) Rydb.
# 684952  ZIVEG          ZIGR2               Zigadenus gramineus Rydb.
# 684953  ZIVEG           ZIIN             Zigadenus intermedius Rydb.
# 684954  ZIZAN            NaN                              Zizania L.
# 684955  ZIZIA            NaN                       Zizia W.D.J. Koch
#
#        State Common Name     Family         State           Genus
# 0             Fraser fir   Pinaceae       Georgia           Abies
# 1                    NaN   Pinaceae       Georgia           Pinus
# 2                    fir   Pinaceae       Georgia           Abies
# 3              rosarypea   Fabaceae       Georgia           Abrus
# 4                    NaN   Fabaceae       Georgia           Abrus
# ...                  ...        ...           ...             ...
# 684951               NaN  Liliaceae  South Dakota  Toxicoscordion
# 684952               NaN  Liliaceae  South Dakota       Zigadenus
# 684953               NaN  Liliaceae  South Dakota       Zigadenus
# 684954          wildrice    Poaceae  South Dakota         Zizania
# 684955             zizia   Apiaceae  South Dakota           Zizia
#
# [684956 rows x 7 columns]

# %%
def sci_names(row):
    try: 
        epithets = re.findall('\s([a-z]+\.*)', row['Scientific Name with Author'])
        full_name = row['Genus']
        for i in epithets:
            full_name += ' ' + i
        return full_name
    except:
        return None

# %%
frame['Scientific name'] = frame.apply(lambda row: sci_names(row), axis=1)

# %% [markdown]
# ### Extract species names

# %%
def species(row):
    try: 
        species = row['Scientific name'].split()[1]
        return species
    except:
        return None

# %%
frame['Species'] = frame.apply(lambda row: species(row), axis=1)

# %% [markdown]
# ### Extract infraspecific names
# functionally: the remainder of the "scientifcc name" after *Genus* and *species*

# %%
def infra(row):
    try: 
        extras = row['Scientific name'].split()[2:]
        infras = ''
        for i in extras:
            infras += ' ' + i
        infras = infras.strip()
        if len(infras) == 0: return None
        else: return infras
    except:
        return None

# %%
frame['Infraspecies name'] = frame.apply(lambda row: infra(row), axis=1)

# %% [markdown]
# Infraspecific names could take the form of:
#
# "var.", "ssp", "subsp.", "forma", "f.", or "nom. inval."
#
# and the regex function could consist of :

# %%
# gs_match = re.search('(var\.|ssp\.|subsp\.|f\.\svar\.|f\.|nom\.\sinval\.)\s[a-z]+', row['Scientific Name with Author'])

# %% [markdown]
# ### Rearrange columns

# %%
frame.columns
# Out:
# Index(['Symbol', 'Synonym Symbol', 'Scientific Name with Author',
#        'State Common Name', 'Family', 'State', 'Genus', 'Scientific name',
#        'Species', 'Infraspecies name'],
#       dtype='object')

# %%
frame
# Out:
#        Symbol Synonym Symbol             Scientific Name with Author  \
# 0        ABFR            NaN             Abies fraseri (Pursh) Poir.
# 1        ABFR           PIFR                     Pinus fraseri Pursh
# 2       ABIES            NaN                             Abies Mill.
# 3       ABPR3            NaN                    Abrus precatorius L.
# 4       ABPR3          ABAB2  Abrus abrus (L.) W. Wight, nom. inval.
# ...       ...            ...                                     ...
# 684951  ZIVEG          TOGR3  Toxicoscordion gramineum (Rydb.) Rydb.
# 684952  ZIVEG          ZIGR2               Zigadenus gramineus Rydb.
# 684953  ZIVEG           ZIIN             Zigadenus intermedius Rydb.
# 684954  ZIZAN            NaN                              Zizania L.
# 684955  ZIZIA            NaN                       Zizia W.D.J. Koch
#
#        State Common Name     Family         State           Genus  \
# 0             Fraser fir   Pinaceae       Georgia           Abies
# 1                    NaN   Pinaceae       Georgia           Pinus
# 2                    fir   Pinaceae       Georgia           Abies
# 3              rosarypea   Fabaceae       Georgia           Abrus
# 4                    NaN   Fabaceae       Georgia           Abrus
# ...                  ...        ...           ...             ...
# 684951               NaN  Liliaceae  South Dakota  Toxicoscordion
# 684952               NaN  Liliaceae  South Dakota       Zigadenus
# 684953               NaN  Liliaceae  South Dakota       Zigadenus
# 684954          wildrice    Poaceae  South Dakota         Zizania
# 684955             zizia   Apiaceae  South Dakota           Zizia
#
#                  Scientific name      Species Infraspecies name
# 0                  Abies fraseri      fraseri              None
# 1                  Pinus fraseri      fraseri              None
# 2                          Abies         None              None
# 3              Abrus precatorius  precatorius              None
# 4        Abrus abrus nom. inval.        abrus       nom. inval.
# ...                          ...          ...               ...
# 684951  Toxicoscordion gramineum    gramineum              None
# 684952       Zigadenus gramineus    gramineus              None
# 684953     Zigadenus intermedius  intermedius              None
# 684954                   Zizania         None              None
# 684955                     Zizia         None              None
#
# [684956 rows x 10 columns]

# %%
frame = frame[['Symbol', 'Synonym Symbol', 'Family', 
              'Scientific Name with Author', 'Scientific name', 
              'Genus', 'Species', 'Infraspecies name', 
              'State Common Name', 'State']]
frame
# Out:
#        Symbol Synonym Symbol     Family  \
# 0        ABFR            NaN   Pinaceae
# 1        ABFR           PIFR   Pinaceae
# 2       ABIES            NaN   Pinaceae
# 3       ABPR3            NaN   Fabaceae
# 4       ABPR3          ABAB2   Fabaceae
# ...       ...            ...        ...
# 684951  ZIVEG          TOGR3  Liliaceae
# 684952  ZIVEG          ZIGR2  Liliaceae
# 684953  ZIVEG           ZIIN  Liliaceae
# 684954  ZIZAN            NaN    Poaceae
# 684955  ZIZIA            NaN   Apiaceae
#
#                    Scientific Name with Author           Scientific name  \
# 0                  Abies fraseri (Pursh) Poir.             Abies fraseri
# 1                          Pinus fraseri Pursh             Pinus fraseri
# 2                                  Abies Mill.                     Abies
# 3                         Abrus precatorius L.         Abrus precatorius
# 4       Abrus abrus (L.) W. Wight, nom. inval.   Abrus abrus nom. inval.
# ...                                        ...                       ...
# 684951  Toxicoscordion gramineum (Rydb.) Rydb.  Toxicoscordion gramineum
# 684952               Zigadenus gramineus Rydb.       Zigadenus gramineus
# 684953             Zigadenus intermedius Rydb.     Zigadenus intermedius
# 684954                              Zizania L.                   Zizania
# 684955                       Zizia W.D.J. Koch                     Zizia
#
#                  Genus      Species Infraspecies name State Common Name  \
# 0                Abies      fraseri              None        Fraser fir
# 1                Pinus      fraseri              None               NaN
# 2                Abies         None              None               fir
# 3                Abrus  precatorius              None         rosarypea
# 4                Abrus        abrus       nom. inval.               NaN
# ...                ...          ...               ...               ...
# 684951  Toxicoscordion    gramineum              None               NaN
# 684952       Zigadenus    gramineus              None               NaN
# 684953       Zigadenus  intermedius              None               NaN
# 684954         Zizania         None              None          wildrice
# 684955           Zizia         None              None             zizia
#
#                State
# 0            Georgia
# 1            Georgia
# 2            Georgia
# 3            Georgia
# 4            Georgia
# ...              ...
# 684951  South Dakota
# 684952  South Dakota
# 684953  South Dakota
# 684954  South Dakota
# 684955  South Dakota
#
# [684956 rows x 10 columns]
